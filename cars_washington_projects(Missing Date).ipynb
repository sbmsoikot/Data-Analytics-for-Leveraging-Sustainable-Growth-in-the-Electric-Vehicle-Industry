# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# from datetime import dateime
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.ticker as mtick
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('ELECTREG.CSV')

df
# Out:
#        Clean Alternative Fuel Vehicle Type  VIN (1-10)  DOL Vehicle ID  \
# 0           Battery Electric Vehicle (BEV)  5YJSA1CN4D       281040350
# 1           Battery Electric Vehicle (BEV)  5YJSA1H17E       190417853
# 2           Battery Electric Vehicle (BEV)  5YJSA1DP6D       137019942
# 3           Battery Electric Vehicle (BEV)  5YJSA1DP1D       239433008
# 4           Battery Electric Vehicle (BEV)  5YJSA1H14E       149926332
# ...                                    ...         ...             ...
# 832173      Battery Electric Vehicle (BEV)  5YJ3E1EC8P       220999229
# 832174      Battery Electric Vehicle (BEV)  KNDC3DLCXN       220351918
# 832175      Battery Electric Vehicle (BEV)  5YJSA1E50N       253247942
# 832176      Battery Electric Vehicle (BEV)  5YJSA1E21J       220643132
# 832177      Battery Electric Vehicle (BEV)  JN1AZ0CP1B       133789183
#
#         Model Year    Make    Model Vehicle Primary Use  Electric Range  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 832178 entries, 0 to 832177
# Data columns (total 35 columns):
#  #   Column                                                          Non-Null Count   Dtype
# ---  ------                                                          --------------   -----
#  0   Clean Alternative Fuel Vehicle Type                             832178 non-null  object
#  1   VIN (1-10)                                                      832178 non-null  object
#  2   DOL Vehicle ID                                                  832178 non-null  int64
#  3   Model Year                                                      832178 non-null  int64
#  4   Make                                                            832178 non-null  object
#  5   Model                                                           832178 non-null  object
#  6   Vehicle Primary Use                                             832178 non-null  object
# ...

# %%
df['County'] = df.County.fillna(method = 'ffill')

df1 = df

# %%
df1['City'] = df1.City.fillna(method = 'ffill')

df2=df1

# %%
df2['State of Residence'] = df2['State of Residence'].fillna(method = 'ffill')

df3=df2

# %%
df3['Sale Date'] = df3['Sale Date'].fillna(method = 'ffill')

df4=df3

# %%
df5 = df4.drop(columns=['Postal Code', '2015 HB 2778 Exemption Eligibility', '2019 HB 2042 Clean Alternative Fuel Vehicle (CAFV) Eligibility',
                       'Meets 2019 HB 2042 Electric Range Requirement', 'Meets 2019 HB 2042 Sale Date Requirement',
                       'Meets 2019 HB 2042 Sale Price/Value Requirement', '2019 HB 2042: Battery Range Requirement',
                       '2019 HB 2042: Purchase Date Requirement', '2019 HB 2042: Sale Price/Value Requirement', 'Electric Vehicle Fee Paid',
                       'Transportation Electrification Fee Paid', 'Hybrid Vehicle Electrification Fee Paid', '2020 Census Tract',
                       'Legislative District', 'Electric Utility'])

# %%
df5
# Out:
#        Clean Alternative Fuel Vehicle Type  VIN (1-10)  DOL Vehicle ID  \
# 0           Battery Electric Vehicle (BEV)  5YJSA1CN4D       281040350
# 1           Battery Electric Vehicle (BEV)  5YJSA1H17E       190417853
# 2           Battery Electric Vehicle (BEV)  5YJSA1DP6D       137019942
# 3           Battery Electric Vehicle (BEV)  5YJSA1DP1D       239433008
# 4           Battery Electric Vehicle (BEV)  5YJSA1H14E       149926332
# ...                                    ...         ...             ...
# 832173      Battery Electric Vehicle (BEV)  5YJ3E1EC8P       220999229
# 832174      Battery Electric Vehicle (BEV)  KNDC3DLCXN       220351918
# 832175      Battery Electric Vehicle (BEV)  5YJSA1E50N       253247942
# 832176      Battery Electric Vehicle (BEV)  5YJSA1E21J       220643132
# 832177      Battery Electric Vehicle (BEV)  JN1AZ0CP1B       133789183
#
#         Model Year    Make    Model Vehicle Primary Use  Electric Range  \
# ...

# %%
df5.to_csv('sustain.csv', index = False)

# %%
su = pd.read_csv('sustain.csv')

su
# Out:
#        Clean Alternative Fuel Vehicle Type  VIN (1-10)  DOL Vehicle ID  \
# 0           Battery Electric Vehicle (BEV)  5YJSA1CN4D       281040350
# 1           Battery Electric Vehicle (BEV)  5YJSA1H17E       190417853
# 2           Battery Electric Vehicle (BEV)  5YJSA1DP6D       137019942
# 3           Battery Electric Vehicle (BEV)  5YJSA1DP1D       239433008
# 4           Battery Electric Vehicle (BEV)  5YJSA1H14E       149926332
# ...                                    ...         ...             ...
# 832173      Battery Electric Vehicle (BEV)  5YJ3E1EC8P       220999229
# 832174      Battery Electric Vehicle (BEV)  KNDC3DLCXN       220351918
# 832175      Battery Electric Vehicle (BEV)  5YJSA1E50N       253247942
# 832176      Battery Electric Vehicle (BEV)  5YJSA1E21J       220643132
# 832177      Battery Electric Vehicle (BEV)  JN1AZ0CP1B       133789183
#
#         Model Year    Make    Model Vehicle Primary Use  Electric Range  \
# ...

# %%
su.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 832178 entries, 0 to 832177
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Clean Alternative Fuel Vehicle Type  832178 non-null  object
#  1   VIN (1-10)                           832178 non-null  object
#  2   DOL Vehicle ID                       832178 non-null  int64
#  3   Model Year                           832178 non-null  int64
#  4   Make                                 832178 non-null  object
#  5   Model                                832178 non-null  object
#  6   Vehicle Primary Use                  832178 non-null  object
#  7   Electric Range                       832178 non-null  int64
#  8   Odometer Reading                     832178 non-null  int64
#  9   Odometer Code                        832178 non-null  object
#  10  New or Used Vehicle                  832178 non-null  object
# ...

# %%
su[su['Sale Price'] == 0]
# Out:
#        Clean Alternative Fuel Vehicle Type  VIN (1-10)  DOL Vehicle ID  \
# 0           Battery Electric Vehicle (BEV)  5YJSA1CN4D       281040350
# 1           Battery Electric Vehicle (BEV)  5YJSA1H17E       190417853
# 2           Battery Electric Vehicle (BEV)  5YJSA1DP6D       137019942
# 3           Battery Electric Vehicle (BEV)  5YJSA1DP1D       239433008
# 4           Battery Electric Vehicle (BEV)  5YJSA1H14E       149926332
# ...                                    ...         ...             ...
# 832173      Battery Electric Vehicle (BEV)  5YJ3E1EC8P       220999229
# 832174      Battery Electric Vehicle (BEV)  KNDC3DLCXN       220351918
# 832175      Battery Electric Vehicle (BEV)  5YJSA1E50N       253247942
# 832176      Battery Electric Vehicle (BEV)  5YJSA1E21J       220643132
# 832177      Battery Electric Vehicle (BEV)  JN1AZ0CP1B       133789183
#
#         Model Year    Make    Model Vehicle Primary Use  Electric Range  \
# ...

# %%
su = pd.read_csv('sustain.csv')

su
# Out:
#        Clean Alternative Fuel Vehicle Type  VIN (1-10)  DOL Vehicle ID  \
# 0           Battery Electric Vehicle (BEV)  5YJSA1CN4D       281040350
# 1           Battery Electric Vehicle (BEV)  5YJSA1H17E       190417853
# 2           Battery Electric Vehicle (BEV)  5YJSA1DP6D       137019942
# 3           Battery Electric Vehicle (BEV)  5YJSA1DP1D       239433008
# 4           Battery Electric Vehicle (BEV)  5YJSA1H14E       149926332
# ...                                    ...         ...             ...
# 832173      Battery Electric Vehicle (BEV)  5YJ3E1EC8P       220999229
# 832174      Battery Electric Vehicle (BEV)  KNDC3DLCXN       220351918
# 832175      Battery Electric Vehicle (BEV)  5YJSA1E50N       253247942
# 832176      Battery Electric Vehicle (BEV)  5YJSA1E21J       220643132
# 832177      Battery Electric Vehicle (BEV)  JN1AZ0CP1B       133789183
#
#         Model Year    Make    Model Vehicle Primary Use  Electric Range  \
# ...

# %%
su['Sale Date']= pd.to_datetime(su['Sale Date'])

# %%
su.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 832178 entries, 0 to 832177
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Clean Alternative Fuel Vehicle Type  832178 non-null  object
#  1   VIN (1-10)                           832178 non-null  object
#  2   DOL Vehicle ID                       832178 non-null  int64
#  3   Model Year                           832178 non-null  int64
#  4   Make                                 832178 non-null  object
#  5   Model                                832178 non-null  object
#  6   Vehicle Primary Use                  832178 non-null  object
#  7   Electric Range                       832178 non-null  int64
#  8   Odometer Reading                     832178 non-null  int64
#  9   Odometer Code                        832178 non-null  object
#  10  New or Used Vehicle                  832178 non-null  object
# ...
